# %%
from matplotlib import pyplot as plt

# %% [markdown]
# ## Graphics from the original paper:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Version of follow graphics with mse in train dataset

# %%
# train mse
fig = plt.figure(figsize=[15, 5])

plt.subplot(1, 3, 1).set_xscale('log')
plt.plot([178, 597, 2152, 8144, 31648, 124736], [0.47, 0.01, 0.0, 0.0, 0.01, 0.01])
plt.plot([178, 597, 2152, 8144, 31648, 124736], [0.464, 0.25, 0.004, 0.002, 0.0, 0.0])
plt.plot([178, 597, 2152, 8144, 31648, 124736], [0.434, 0.268, 0.0148, 0.0012, 0.0004, 0.0004])
plt.title("Feasibility")
plt.legend(['Num of Samp: 100', 'Num of Samp: 500', 'Num of Samp: 2500'])
plt.xlabel("Num. of GNN parameters")
plt.ylabel("Rate of erros")

plt.subplot(1, 3, 2).set_xscale('log')
plt.plot([178, 597, 2152, 8144, 31648, 124736], [0.11493312567472458, 0.0018822142155840993, 2.323347135339826e-13, 5.76988475986355e-14, 2.0681790020805543e-14, 7.71882574811299e-15])
plt.plot([178, 597, 2152, 8144, 31648, 124736], [1.1628559827804565, 0.05748189240694046, 0.0028491481207311153, 8.928901706894976e-08, 2.776220551191366e-13, 6.533632006732945e-14])
plt.plot([178, 597, 2152, 8144, 31648, 124736], [0.16289687156677246, 0.11555006355047226, 0.06696827709674835, 0.00572791276499629, 1.117395640903851e-05, 1.5235392538670567e-06])
plt.title("Optimal objetive value")
plt.legend(['Num of Samp: 100', 'Num of Samp: 500', 'Num of Samp: 2500'])
plt.xlabel("Num. of GNN parameters")
plt.ylabel("Mean squared error")

plt.subplot(1, 3, 3).set_xscale('log')
plt.plot([8144, 31648, 124736, 478848, 1907968, 7617024], [23.804304122924805, 7.117199420928955, 4.520870685577393, 2.746967077255249, 0.2076386958360672, 0.00019912212155759335])
plt.plot([8144, 31648, 124736, 478848, 1907968, 7617024], [49.2032356262207, 26.996868133544922, 10.667935371398926, 6.43810510635376, 4.158440113067627, 0.2357875406742096])
plt.plot([8144, 31648, 124736, 478848], [45.755462646484375, 40.95026397705078, 26.572458267211914, 11.551281929016113])
plt.title("Optimal solution")
plt.legend(['Num of Samp: 100', 'Num of Samp: 500', 'Num of Samp: 2500'])
plt.xlabel("Num. of GNN parameters")
plt.ylabel("Mean squared error")

plt.show()

# %% [markdown]
# ### Version of follow graphics with mse in test dataset

# %%
# test mse

fig = plt.figure(figsize=[15, 5])

plt.subplot(1, 3, 1).set_xscale('log')
plt.plot([178, 597, 2152, 8144, 31648, 124736], [0.518, 0.422, 0.429, 0.401, 0.415, 0.414])
plt.plot([178, 597, 2152, 8144, 31648, 124736], [0.514, 0.454, 0.403, 0.413, 0.344, 0.336])
plt.plot([178, 597, 2152, 8144, 31648, 124736], [0.433, 0.314, 0.19, 0.256, 0.259, 0.291])
plt.title("Feasibility")
plt.legend(['Num of Samp: 100', 'Num of Samp: 500', 'Num of Samp: 2500'])
plt.xlabel("Num. of GNN parameters")
plt.ylabel("Rate of erros")

plt.subplot(1, 3, 2).set_xscale('log')
plt.plot([178, 597, 2152, 8144, 31648, 124736], [0.19740068912506104, 0.4662117063999176, 0.38120344281196594, 0.23586997389793396, 0.19051741063594818, 0.192531019449234])
plt.plot([178, 597, 2152, 8144, 31648, 124736], [1.207754135131836, 0.2001756727695465, 0.3791002929210663, 0.3572259545326233, 0.25358232855796814, 0.2292686402797699])
plt.plot([178, 597, 2152, 8144, 31648, 124736], [0.18535208702087402, 0.13980314135551453, 0.21315841376781464, 0.46831437945365906, 0.3404199182987213, 0.22360233962535858])
plt.title("Optimal objetive value")
plt.legend(['Num of Samp: 100', 'Num of Samp: 500', 'Num of Samp: 2500'])
plt.xlabel("Num. of GNN parameters")
plt.ylabel("Mean squared error")

plt.subplot(1, 3, 3).set_xscale('log')
plt.plot([8144, 31648, 124736, 478848, 1907968, 7617024], [259.76275634765625, 594.0967407226562, 317.71380615234375, 142.15989685058594, 91.22662353515625, 85.08019256591797])
plt.plot([8144, 31648, 124736, 478848, 1907968, 7617024], [93.78468322753906, 141.4667205810547, 293.6853332519531, 205.8374786376953, 98.61176300048828, 83.25299835205078])
plt.plot([8144, 31648, 124736, 478848], [53.17569351196289, 68.96418762207031, 105.15486145019531, 188.18223571777344])
plt.title("Optimal solution")
plt.legend(['Num of Samp: 100', 'Num of Samp: 500', 'Num of Samp: 2500'])
plt.xlabel("Num. of GNN parameters")
plt.ylabel("Mean squared error")

plt.show()

# %% [markdown]
# ### Version of follow graphics with l2 in train dataset

# %%
# train l2

fig = plt.figure(figsize=[15, 5])

plt.subplot(1, 3, 1).set_xscale('log')
plt.plot([178, 597, 2152, 8144, 31648, 124736], [0.47, 0.01, 0.0, 0.0, 0.01, 0.01])
plt.plot([178, 597, 2152, 8144, 31648, 124736], [0.464, 0.25, 0.004, 0.002, 0.0, 0.0])
plt.plot([178, 597, 2152, 8144, 31648, 124736], [0.434, 0.268, 0.0148, 0.0012, 0.0004, 0.0004])
plt.title("Feasibility")
plt.legend(['Num of Samp: 100', 'Num of Samp: 500', 'Num of Samp: 2500'])
plt.xlabel("Num. of GNN parameters")
plt.ylabel("Rate of erros")

plt.subplot(1, 3, 2).set_xscale('log')
plt.plot([178, 597, 2152, 8144, 31648, 124736], [0.14931604266166687, 0.012360277585685253, 1.8759583042537997e-07, 9.059204586492342e-08, 5.781828704698455e-08, 2.7823602977150586e-08])
plt.plot([178, 597, 2152, 8144, 31648, 124736], [0.48446959257125854, 0.11814935505390167, 0.014867114834487438, 8.966397581389174e-05, 1.929993800331431e-07, 1.0064872668635871e-07])
plt.plot([178, 597, 2152, 8144, 31648, 124736], [0.16821347177028656, 0.14827370643615723, 0.10454429686069489, 0.02837773784995079, 0.0012017427943646908, 0.0004624107386916876])
plt.title("Optimal objetive value")
plt.legend(['Num of Samp: 100', 'Num of Samp: 500', 'Num of Samp: 2500'])
plt.xlabel("Num. of GNN parameters")
plt.ylabel("Mean squared error")

plt.subplot(1, 3, 3).set_xscale('log')
plt.plot([8144, 31648, 124736, 478848, 1907968, 7617024], [0.5189362168312073, 0.27472785115242004, 0.20991766452789307, 0.16310131549835205, 0.04042999818921089, 0.001040515024214983])
plt.plot([8144, 31648, 124736, 478848, 1907968, 7617024], [0.7535871863365173, 0.540357768535614, 0.3329913020133972, 0.24678443372249603, 0.18938946723937988, 0.041764385998249054])
plt.plot([8144, 31648, 124736, 478848], [0.6697690486907959, 0.6446653604507446, 0.5228433012962341, 0.34190258383750916])
plt.title("Optimal solution")
plt.legend(['Num of Samp: 100', 'Num of Samp: 500', 'Num of Samp: 2500'])
plt.xlabel("Num. of GNN parameters")
plt.ylabel("Mean squared error")

plt.show()

# %% [markdown]
# ### Version of follow graphics with l2 in test dataset

# %%
# train l2

fig = plt.figure(figsize=[15, 5])

plt.subplot(1, 3, 1).set_xscale('log')
plt.plot([178, 597, 2152, 8144, 31648, 124736], [0.518, 0.422, 0.429, 0.401, 0.415, 0.414])
plt.plot([178, 597, 2152, 8144, 31648, 124736], [0.514, 0.454, 0.403, 0.413, 0.344, 0.336])
plt.plot([178, 597, 2152, 8144, 31648, 124736], [0.433, 0.314, 0.19, 0.256, 0.259, 0.291])
plt.title("Feasibility")
plt.legend(['Num of Samp: 100', 'Num of Samp: 500', 'Num of Samp: 2500'])
plt.xlabel("Num. of GNN parameters")
plt.ylabel("Rate of erros")

plt.subplot(1, 3, 2).set_xscale('log')
plt.plot([178, 597, 2152, 8144, 31648, 124736], [0.171969935297966, 0.2634255886077881, 0.23760873079299927, 0.19465996325016022, 0.17639243602752686, 0.1768324375152588])
plt.plot([178, 597, 2152, 8144, 31648, 124736], [0.4927770495414734, 0.17881065607070923, 0.2474592626094818, 0.241669699549675, 0.20125147700309753, 0.19243429601192474])
plt.plot([178, 597, 2152, 8144, 31648, 124736], [0.16464708745479584, 0.1508375108242035, 0.1829303652048111, 0.26138731837272644, 0.23170368373394012, 0.19149473309516907])
plt.title("Optimal objetive value")
plt.legend(['Num of Samp: 100', 'Num of Samp: 500', 'Num of Samp: 2500'])
plt.xlabel("Num. of GNN parameters")
plt.ylabel("Mean squared error")

plt.subplot(1, 3, 3).set_xscale('log')
plt.plot([8144, 31648, 124736, 478848, 1907968, 7617024], [1.634502649307251, 2.520228385925293, 1.9001355171203613, 1.2776684761047363, 1.0213959217071533, 0.9799932837486267])
plt.plot([8144, 31648, 124736, 478848, 1907968, 7617024], [1.005482792854309, 1.2264903783798218, 1.8031057119369507, 1.5283033847808838, 1.057359218597412, 0.9615333676338196])
plt.plot([8144, 31648, 124736, 478848], [0.7224816083908081, 0.8282796740531921, 1.0659443140029907, 1.4430433511734009])
plt.title("Optimal solution")
plt.legend(['Num of Samp: 100', 'Num of Samp: 500', 'Num of Samp: 2500'])
plt.xlabel("Num. of GNN parameters")
plt.ylabel("Mean squared error")

plt.show()

# %% [markdown]
# #  Tables from the original appendice paper

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ### Generalization for feasibility
# | Number of Training Samples    | 100  | 500   | 2500  |
# |-------------------------------|------|-------|-------|
# | The Error on the training set | 0.45 | 0.392 | 0.298 |
# | The Error on the testing set  | 0.48 | 0.437 | 0.299 |
#
# ### Generalization for optimal objective value
# | Number of Training Samples    | 100   | 500   | 2500  |
# |-------------------------------|-------|-------|-------|
# | The Error on the training set | 0.019 | 0.056 | 0.126 |
# | The Error on the testing set  | 0.293 | 0.248 | 0.164 |
#
# ### Generalization for optimal solution
# | Number of Training Samples    | 100   | 500   | 2500  |
# |-------------------------------|-------|-------|-------|
# | The Error on the training set | 0.518 | 0.753 | 0.669 |
# | The Error on the testing set  | 1.634 | 1.005 | 0.722 |
