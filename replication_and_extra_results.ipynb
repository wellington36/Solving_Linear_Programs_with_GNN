# %%
from matplotlib import pyplot as plt

# %% [markdown]
# ## Graphics from the original paper:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Version of follow graphics with mse in train dataset

# %%
# train mse
fig = plt.figure(figsize=[15, 5])

plt.subplot(1, 3, 1)
plt.plot([1, 2, 3, 4, 5, 6], [0.14, 0.47, 0.0, 0.0, 0.0, 0.0])
plt.plot([1, 2, 3, 4, 5, 6], [0.466, 0.032, 0.0, 0.0, 0.0, 0.0])
plt.plot([1, 2, 3, 4, 5, 6], [0.3508, 0.4992, 0.092, 0.0016, 0.0, 0.0])

plt.subplot(1, 3, 2)
plt.plot([1, 2, 3, 4, 5, 6], [0.11493312567472458, 0.0018822142155840993, 2.323347135339826e-13, 5.76988475986355e-14, 2.0681790020805543e-14, 7.71882574811299e-15])
plt.plot([1, 2, 3, 4, 5, 6], [1.1628559827804565, 0.05748189240694046, 0.0028491481207311153, 8.928901706894976e-08, 2.776220551191366e-13, 6.533632006732945e-14])
plt.plot([1, 2, 3, 4, 5, 6], [0.16289687156677246, 0.11555006355047226, 0.06696827709674835, 0.00572791276499629, 1.117395640903851e-05, 1.5235392538670567e-06])

plt.subplot(1, 3, 3)
plt.plot([1, 2, 3, 4, 5, 6], [23.804304122924805, 7.117199420928955, 4.520870685577393, 2.746967077255249, 0.2076386958360672, 0.00019912212155759335])
plt.plot([1, 2, 3, 4, 5, 6], [49.2032356262207, 26.996868133544922, 10.667935371398926, 6.43810510635376, 4.158440113067627, 0.2357875406742096])
plt.plot([1, 2, 3, 4], [45.755462646484375, 40.95026397705078, 26.572458267211914, 11.551281929016113])

# %% [markdown]
# ### Version of follow graphics with mse in test dataset

# %%
# test mse

fig = plt.figure(figsize=[15, 5])

plt.subplot(1, 3, 1)
plt.plot([1, 2, 3, 4, 5, 6], [0.454, 0.518, 0.464, 0.446, 0.393, 0.428])
plt.plot([1, 2, 3, 4, 5, 6], [0.518, 0.44, 0.396, 0.382, 0.345, 0.326])
plt.plot([1, 2, 3, 4, 5, 6], [0.363, 0.518, 0.319, 0.275, 0.278, 0.223])

plt.subplot(1, 3, 2)
plt.plot([1, 2, 3, 4, 5, 6], [0.19740068912506104, 0.4662117063999176, 0.38120344281196594, 0.23586997389793396, 0.19051741063594818, 0.192531019449234])
plt.plot([1, 2, 3, 4, 5, 6], [1.207754135131836, 0.2001756727695465, 0.3791002929210663, 0.3572259545326233, 0.25358232855796814, 0.2292686402797699])
plt.plot([1, 2, 3, 4, 5, 6], [0.18535208702087402, 0.13980314135551453, 0.21315841376781464, 0.46831437945365906, 0.3404199182987213, 0.22360233962535858])

plt.subplot(1, 3, 3)
plt.plot([1, 2, 3, 4, 5, 6], [259.76275634765625, 594.0967407226562, 317.71380615234375, 142.15989685058594, 91.22662353515625, 85.08019256591797])
plt.plot([1, 2, 3, 4, 5, 6], [93.78468322753906, 141.4667205810547, 293.6853332519531, 205.8374786376953, 98.61176300048828, 83.25299835205078])
plt.plot([1, 2, 3, 4], [53.17569351196289, 68.96418762207031, 105.15486145019531, 188.18223571777344])

plt.show()

# %% [markdown]
# ### Version of follow graphics with l2 in train dataset

# %%
plt.plot([1, 2, 3, 4, 5, 6], [

# %% [markdown]
# ### Version of follow graphics with l2 in test dataset

# %% [markdown]
# #  Tables from the original appendice paper

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ### Generalization for feasibility
# | Number of Training Samples    | 100  | 500   | 2500  |
# |-------------------------------|------|-------|-------|
# | The Error on the training set | 0.45 | 0.392 | 0.298 |
# | The Error on the testing set  | 0.48 | 0.437 | 0.299 |
#
# ### Generalization for optimal objective value
# | Number of Training Samples    | 100   | 500   | 2500  |
# |-------------------------------|-------|-------|-------|
# | The Error on the training set | 0.019 | 0.056 | 0.126 |
# | The Error on the testing set  | 0.293 | 0.248 | 0.164 |
#
# ### Generalization for optimal solution
# | Number of Training Samples    | 100   | 500   | 2500  |
# |-------------------------------|-------|-------|-------|
# | The Error on the training set | 0.518 | 0.753 | 0.669 |
# | The Error on the testing set  | 1.634 | 1.005 | 0.722 |
